# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# Define function f
def f(x):
    return x

# Create an array of x values from 0 to 10
x = range(0, 11)

# Get the corresponding y values from the function
y = [f(a) for a in x]

# Set up the plot
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid()

# Plot x against f(x)
plt.plot(x,y, color='purple')

plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from matplotlib import pyplot as plt
# %matplotlib inline
# Set up the plot
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid()

# Plot x against f(x)
plt.plot(x,y, color='purple')

# show area for integral
section = np.arange(0, 2, 0.05)
plt.fill_between(section,f(section), color='orange')

plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import scipy.integrate as integrate
i, e = integrate.quad(lambda x: f(x), 0, 2)
print (i)
print (e)
# Out:
# 2.0
# 2.22044604925e-14

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.patches import Polygon
# %matplotlib inline

#define function g
def g(x):
    return 3 * x**2 + 2*x + 1

#create an array of x values from 0 to 10
x = range(0,11)

#get the corresponding y values from the function
y = [g(i) for i in x]

#set up the plot
fig, ax = plt.subplots()
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid()

#plot x againsts g(x)
plt.plot(x, y, color='purple')

#make the shaded region
ix = np.linspace(0,3)
iy = g(ix)
verts = [(0, 0)] + list(zip(ix, iy)) + [(3, 0)]
poly = Polygon(verts, facecolor='orange')
ax.add_patch(poly)

plt.show()

i, e = integrate.quad(lambda x: g(x), 0, 3)
print (i)
# Out:
# 39.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Note that the result from the scipy.integrate.quad function is approximate - the function actually returns an estimated integral (i in this case) and also a measure of absolute error (e). Run the following code to see what the absolute error was in this case:
print (e)
# Out:
# 4.32986979604e-13

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
i, e = integrate.quad(lambda x: np.exp(-x*5), 0, np.inf)

print('Integral: ' + str(i))
print('Absolute Error: ' + str(e))
# Out:
# Integral: 0.2
# Absolute Error: 1.56066669593e-11

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
norms = lambda x: np.exp(-x**2/2.0)/np.sqrt(2.0 * 3.14159)
i, e = integrate.quad(norms, -np.inf, np.inf)

print('Integral: ' + str(i))
print('Absolute Error: ' + str(e))
# Out:
# Integral: 1.00000042233
# Absolute Error: 1.01781956956e-08

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

def k(x):
    return -2*x**2 + 30 * x +3

x = range(-10, 11)
y = [k(i) for i in x]

plt.plot(x, y)
plt.grid()
plt.show()
