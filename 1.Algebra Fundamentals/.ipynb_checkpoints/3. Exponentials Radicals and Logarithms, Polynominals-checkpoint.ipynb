# %%
#exponentials
x = 5**3
print (x)
# Out:
# 125

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import math
#calculate square root of 25
x = math.sqrt(25)
print (x)
#calculate cube root of 64
cr = round(64 ** (1. / 3))
print (cr)
# Out:
# 5.0
# 4.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import math
x = math.log(16, 4)
print (x)
# Out:
# 2.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import math

#natural log of 29
print (math.log(29))

#common log of 100
print (math.log10(100))
# Out:
# 3.36729582999
# 2.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# 2y = 6x**3
# y = 3x**3

# %%
import pandas as pd

df = pd.DataFrame({'x': range(-10, 11)})
df['y'] = 3*df['x']**3
print (df)

# %matplotlib inline
from matplotlib import pyplot as plt
plt.plot(df.x, df.y, color = 'magenta')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.axhline()
plt.axvline()
plt.show()
# Out:
#      x     y
# 0  -10 -3000
# 1   -9 -2187
# 2   -8 -1536
# 3   -7 -1029
# 4   -6  -648
# 5   -5  -375
# 6   -4  -192
# 7   -3   -81
# 8   -2   -24
# 9   -1    -3
# 10   0     0
# 11   1     3
# 12   2    24
# 13   3    81
# 14   4   192
# 15   5   375
# 16   6   648
# 17   7  1029
# 18   8  1536
# 19   9  2187
# 20  10  3000

# %%
#note that the line is curved, this is symptomatic of an exponential equation.
y = 2**x
#we can still plot this as a line:

# %%
df = pd.DataFrame({'x': range(-10, 11)})
df['y'] = 2.0**df['x']
df
# Out:
#      x            y
# 0  -10     0.000977
# 1   -9     0.001953
# 2   -8     0.003906
# 3   -7     0.007812
# 4   -6     0.015625
# 5   -5     0.031250
# 6   -4     0.062500
# 7   -3     0.125000
# 8   -2     0.250000
# 9   -1     0.500000
# 10   0     1.000000
# 11   1     2.000000
# 12   2     4.000000
# 13   3     8.000000
# 14   4    16.000000
# 15   5    32.000000
# 16   6    64.000000
# 17   7   128.000000
# 18   8   256.000000
# 19   9   512.000000
# 20  10  1024.000000

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
plt.plot(df.x, df.y, color='magenta')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.axhline()
plt.axvline()
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
df = pd.DataFrame({'Year': range(1, 21)})
df['Balance'] = 100 * (1.05**df['Year'])
df
# Out:
#     Year     Balance
# 0      1  105.000000
# 1      2  110.250000
# 2      3  115.762500
# 3      4  121.550625
# 4      5  127.628156
# 5      6  134.009564
# 6      7  140.710042
# 7      8  147.745544
# 8      9  155.132822
# 9     10  162.889463
# 10    11  171.033936
# 11    12  179.585633
# 12    13  188.564914
# 13    14  197.993160
# 14    15  207.892818
# 15    16  218.287459
# 16    17  229.201832
# 17    18  240.661923
# 18    19  252.695020
# 19    20  265.329771

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
plt.plot(df.Year, df.Balance, color="green")
plt.xlabel('Year')
plt.ylabel('Balance')
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from random import randint
x = randint(1,100)

(x**4 + 2)*(2*x**2 + 3*x - 3) == 2*x**6 + 3*x**5 - 3*x**4 + 4*x**2 + 6*x - 6
# Out:
# True

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from random import randint
x = randint(1,100)

(4*x + 6*x**2) / (2*x) == 2 + 3*x
# Out:
# True

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image.png](attachment:image.png)

# %%
from random import randint
x = randint(3,100)

(x**2 + 2*x -3)/(x-2) == x + 4 + (5/(x-2))
# Out:
# True
