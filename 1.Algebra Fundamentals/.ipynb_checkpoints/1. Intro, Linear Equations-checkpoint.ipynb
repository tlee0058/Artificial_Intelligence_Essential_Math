# %% [markdown]
# Consider the following equation: x + 16 = -25

# %%
x = -41
x + 16 == -25

# %% [markdown]
# Two-Step Equations
# 3x - 2 = 10
# 3x = 12
# x = 4

# %%
x = 4
3*x - 2 == 10

# %% [markdown]
# Working with Fractions
# (x/3) + 1 = 16
# x = 45

# %%
x = 45
x/3 + 1 == 16

# %% [raw]
# Equation with Variables on Both sides
# 3x + 2 = 5x - 1

# %%
x = 1.5
3*x + 2 == 5*x -1

# %% [markdown]
# Using the Distributive Property
# 4(x + 2) + 3(x-2) = 16

# %%
x = 2
4*(x + 2) + 3*(x - 2) == 16

# %% [raw]
# Solving a Linear Equation
# 2y + 3 = 3x - 1
# y = (3x-4)/2
# You can view the values of y for a range of x values by applying the
# equation to them using the following Python Code:

# %%
import pandas as pd
#create a dataframe with an x column containing values from -10 to 10
df = pd.DataFrame({'x': range(-10, 11)})
#add a y column by applying the solved equation to x
df['y'] = (3* df['x'] - 4) /2
#display the dataframe
df

# %%
#plot the result
# %matplotlib inline
from matplotlib import pyplot as plt
plt.plot(df.x, df.y, color="grey", marker = "o")
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.show()

# %%
#Intercepts
plt.plot(df.x, df.y, color = "grey")
plt.xlabel('x')
plt.ylabel('y')
plt.grid()

#add axis lines for 0, 0
plt.axhline()
plt.axvline()
plt.show()

# %% [raw]
# The x-intercept is the point where the line crosses the X axis, and at this
# point, the y value is always 0
# For the x intercept our equation looks like this:
# 0 = (3x-4)/2
# x = 4/3
# y = -2
# This gives us our y-intercept, so we can plot both intercepts on the graph:

# %%
plt.plot(df.x, df.y, color="grey")
plt.xlabel('x')
plt.ylabel('y')
plt.grid()

## add axis lines for 0, 0
plt.axhline()
plt.axvline()
plt.annotate('x-intercept', (1.333, 0))
plt.annotate('y-intercept', (0, -2))
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#slope above is 1.5
#plot the slope onto the original line

# %%
plt.plot(df.x, df.y, color="grey")
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.axhline()
plt.axvline()

m = 1.5 
yInt = -2

#plot the slope from the y-intercept for 1x
mx = [0, 1]
my = [yInt, yInt + m]
plt.plot(mx, my, color = 'red', lw = 5)

plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# %matplotlib inline
import pandas as pd
from matplotlib import pyplot as plt

df = pd.DataFrame({'x': range(-10, 11)})
m = 1.5
yInt = -2

df['y'] = m * df['x'] + yInt

plt.plot(df.x, df.y, color='grey')
plt.xlabel('x')
plt.ylabel('y')
plt.axhline()
plt.axvline()
plt.grid()

plt.annotate('y-intercept', (0, yInt))

mx = [0, 1]
my = [yInt, yInt + m]
plt.plot(mx, my, color='red', lw=5)
plt.show()
